# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from numpy.random import randn
from scipy import stats
from pandas_ods_reader import read_ods
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
# %matplotlib inline

# %%
Document=pd.read_csv('/home/dajuma/Documents/DANJUMA BAKERY DATAS /danjuma.csv')

# %%
Document.head()
# Out:
#           NAME     O2     O4  SWEET&MILK PATANLA  ₦270  M PATANLA  JAY JAY  \
# 0       ZARUMI  160.0   40.0          42      15  30.0        NaN    290.0
# 1  SMALL TANKE  170.0   32.0          36       8   NaN        5.0    300.0
# 2     IYA DAUD  200.0   50.0          70     NaN  20.0        NaN    350.0
# 3     ROHEEMAT  220.0  110.0          65      60   NaN        NaN    320.0
# 4         OTTE  260.0   55.0          75      20  20.0        NaN    400.0
#
#      ₦90  DUGLANS  JUMBO  DRUM  2COLOR TYSIN  1COLOUR
# 0  100.0      NaN    NaN   NaN           NaN     50.0
# 1  185.0      NaN    NaN   NaN           NaN     55.0
# 2    NaN      NaN   10.0   NaN           NaN     80.0
# 3  170.0      NaN    NaN   NaN           NaN    110.0
# 4    NaN      NaN   20.0  10.0           NaN     70.0

# %%
Document['PATANLA'].unique()
# Out:
# array(['15', '8', nan, '60', '20', '24', '12', '10', '16', '1O', '35',
#        '5', '4', '2'], dtype=object)

# %%
Document['PATANLA']>10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12013/153584759.py in <module>
# ----> 1 Document['PATANLA']>10
#
# /usr/lib/python3/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/lib/python3/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# /usr/lib/python3/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
# ...

# %%
Document.info()

# %%
Document.describe()

# %%
 Document.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# dtype: bool

# %%
Document.isnull()
# Out:
#      NAME     O2     O4  SWEET&MILK  PATANLA   ₦270  M PATANLA  JAY JAY  \
# 0   False  False  False       False    False  False       True    False
# 1   False  False  False       False    False   True      False    False
# 2   False  False  False       False     True  False       True    False
# 3   False  False  False       False    False   True       True    False
# 4   False  False  False       False    False  False       True    False
# 5   False  False  False       False    False  False       True    False
# 6   False  False  False       False    False   True       True    False
# 7   False  False  False       False    False   True      False    False
# 8   False  False  False       False    False  False      False    False
# 9   False  False  False       False     True   True      False    False
# 10  False  False   True       False    False   True       True    False
# 11  False  False   True       False     True   True       True    False
# ...

# %%
Document.isna()
# Out:
#      NAME     O2     O4  SWEET&MILK  PATANLA   ₦270  M PATANLA  JAY JAY  \
# 0   False  False  False       False    False  False       True    False
# 1   False  False  False       False    False   True      False    False
# 2   False  False  False       False     True  False       True    False
# 3   False  False  False       False    False   True       True    False
# 4   False  False  False       False    False  False       True    False
# 5   False  False  False       False    False  False       True    False
# 6   False  False  False       False    False   True       True    False
# 7   False  False  False       False    False   True      False    False
# 8   False  False  False       False    False  False      False    False
# 9   False  False  False       False     True   True      False    False
# 10  False  False   True       False    False   True       True    False
# 11  False  False   True       False     True   True       True    False
# ...

# %%
Document.isna().any()
# Out:
# NAME            False
# O2               True
# O4               True
# SWEET&MILK      False
# PATANLA          True
# ₦270             True
# M PATANLA        True
# JAY JAY          True
# ₦90              True
# DUGLANS          True
# JUMBO            True
# DRUM             True
# 2COLOR TYSIN     True
# 1COLOUR          True
# dtype: bool

# %%
Document.isna().sum()
# Out:
# NAME             0
# O2              13
# O4              16
# SWEET&MILK       0
# PATANLA         23
# ₦270            26
# M PATANLA       26
# JAY JAY         13
# ₦90             25
# DUGLANS         38
# JUMBO           23
# DRUM            28
# 2COLOR TYSIN    38
# 1COLOUR         14
# dtype: int64

# %%
Document.isna().any().sum()
# Out:
# 12

# %%
Document['PATANLA']
# Out:
# 0      15
# 1       8
# 2     NaN
# 3      60
# 4      20
# 5      24
# 6      12
# 7      10
# 8      20
# 9     NaN
# 10     16
# 11    NaN
# 12     1O
# 13    NaN
# 14    NaN
# 15     10
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21     35
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30      5
# 31    NaN
# 32    NaN
# 33    NaN
# 34      4
# 35      2
# 36    NaN
# 37    NaN
# Name: PATANLA, dtype: object

# %%
Document['PATANLA'].replace('1O',10, inplace=True )

# %%
Document.fillna(0, inplace=True)

# %%
Document.set_index('NAME', inplace=True)

# %%
#this explain the maximum product peopel carry the most
max_dco=Document.max()
max_dco
# Out:
# /tmp/ipykernel_12013/2868289158.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   max_dco=Document.max()
# O2              260.0
# O4              110.0
# SWEET&MILK      190.0
# ₦270             40.0
# M PATANLA        25.0
# JAY JAY         400.0
# ₦90             185.0
# DUGLANS           0.0
# JUMBO            25.0
# DRUM             25.0
# 2COLOR TYSIN      0.0
# 1COLOUR         130.0
# dtype: float64

# %%
#the minimum product people carry the less or not at all
min_dco=Document.min()
min_dco
# Out:
# /tmp/ipykernel_12013/508037185.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   min_dco=Document.min()
# O2              0.0
# O4              0.0
# SWEET&MILK      5.0
# ₦270            0.0
# M PATANLA       0.0
# JAY JAY         0.0
# ₦90             0.0
# DUGLANS         0.0
# JUMBO           0.0
# DRUM            0.0
# 2COLOR TYSIN    0.0
# 1COLOUR         0.0
# dtype: float64

# %%
concat_max_min=pd.concat([max_dco,min_dco], axis=1) 
concat_max_min
# Out:
#                   0    1
# O2            260.0  0.0
# O4            110.0  0.0
# SWEET&MILK    190.0  5.0
# ₦270           40.0  0.0
# M PATANLA      25.0  0.0
# JAY JAY       400.0  0.0
# ₦90           185.0  0.0
# DUGLANS         0.0  0.0
# JUMBO          25.0  0.0
# DRUM           25.0  0.0
# 2COLOR TYSIN    0.0  0.0
# 1COLOUR       130.0  0.0

# %%
concat_max_min.index
# Out:
# Index(['O2', 'O4', 'SWEET&MILK', '₦270', 'M PATANLA', 'JAY JAY', '₦90',
#        'DUGLANS', 'JUMBO', 'DRUM', '2COLOR TYSIN', '1COLOUR'],
#       dtype='object')

# %%
#the person that pack most product which product did he or she pack the most
sns.barplot(x=1,y=0,data=concat_max_min,hue=concat_max_min.index, width=1)
plt.savefig('product parck the most and less')

# %%
#the person that pack most product which product did he or she pack the most
sns.barplot(x=0,y=concat_max_min.index, data=concat_max_min)
plt.savefig('the most pack product')

# %%
#the min packer plot
sns.histplot(x=min_dco, data=Document)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
#plot of maximum packer
sns.histplot(x=max_dco, data=Document)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
total_product=Document.sum(axis=0)
total_product
# Out:
# /tmp/ipykernel_12013/1088706120.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   total_product=Document.sum(axis=0)
# O2              3188.0
# O4               749.0
# SWEET&MILK      1861.0
# ₦270             189.0
# M PATANLA         95.0
# JAY JAY         5808.0
# ₦90             1079.0
# DUGLANS            0.0
# JUMBO            151.0
# DRUM              92.0
# 2COLOR TYSIN       0.0
# 1COLOUR         1262.0
# dtype: float64

# %%
total_max_min=pd.concat([total_product,min_dco,max_dco],axis=1)

# %%
total_max_min
# Out:
#                    0    1      2
# O2            3188.0  0.0  260.0
# O4             749.0  0.0  110.0
# SWEET&MILK    1861.0  5.0  190.0
# ₦270           189.0  0.0   40.0
# M PATANLA       95.0  0.0   25.0
# JAY JAY       5808.0  0.0  400.0
# ₦90           1079.0  0.0  185.0
# DUGLANS          0.0  0.0    0.0
# JUMBO          151.0  0.0   25.0
# DRUM            92.0  0.0   25.0
# 2COLOR TYSIN     0.0  0.0    0.0
# 1COLOUR       1262.0  0.0  130.0

# %%
sns.histplot(data=total_max_min, y=total_product, x=min_dco, hue=total_max_min.index)
# Out:
# <AxesSubplot:>

# %%
total_product=Document.sum(axis=0)
sns.histplot(data=total_max_min, x=total_product,y=max_dco, hue=total_max_min.index)
# Out:
# /tmp/ipykernel_12013/1023859826.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   total_product=Document.sum(axis=0)
# <AxesSubplot:>

# %%
list_o2=Document['O2']
g=sns.barplot(data=Document,y=list_o2,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_o4=Document['O4']
g=sns.barplot(data=Document,y=list_o4,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_SWEAT=Document['SWEET&MILK']
g=sns.barplot(data=Document,y=list_SWEAT,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_PATANLA=Document['PATANLA']
g=sns.barplot(data=Document,y=list_PATANLA,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12013/847907680.py in <module>
#       1 list_PATANLA=Document['PATANLA']
# ----> 2 g=sns.barplot(data=Document,y=list_PATANLA,x=Document.index)
#       3 g.set_xticklabels(g.get_xticklabels(),rotation=90);
#
# ~/.local/lib/python3.10/site-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# ...

# %%
list_270=Document['₦270']
g=sns.barplot(data=Document,y=list_270,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_MPATANLA=Document['M PATANLA']
g=sns.barplot(data=Document,y=list_MPATANLA,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_jay=Document['JAY JAY']
g=sns.barplot(data=Document,y=list_jay,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_90=Document['₦90']
g=sns.barplot(data=Document,y=list_90,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_DUGLANS=Document['DUGLANS']
g=sns.barplot(data=Document,y=list_DUGLANS,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_JUMBO=Document['JUMBO']
g=sns.barplot(data=Document,y=list_JUMBO,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_DRUM=Document['DRUM']
g=sns.barplot(data=Document,y=list_DRUM,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_2COLOR=Document['2COLOR TYSIN']
g=sns.barplot(data=Document,y=list_2COLOR,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);

# %%
list_1COLOUR=Document['1COLOUR']
g=sns.barplot(data=Document,y=list_1COLOUR,x=Document.index)
g.set_xticklabels(g.get_xticklabels(),rotation=90);
